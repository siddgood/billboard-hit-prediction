# %%
import pandas as pd
import numpy as np
from tqdm import tqdm

# %% [markdown]
# # Billboard Year-End Hot 100 Charts 2000-2018

# %%
billboard100_df = pd.DataFrame(columns=['Title', 'Artist', 'Year'])
billboard100_df
# Out:
# Empty DataFrame
# Columns: [Title, Artist, Year]
# Index: []

# %%
url_template = 'https://en.wikipedia.org/wiki/Billboard_Year-End_Hot_100_singles_of_'

years = [2000, 2001, 2002, 2003, 2004, 2005, 2006, 
         2007, 2008, 2009, 2010, 2011, 2012, 2013,
         2014, 2015, 2016, 2017, 2018]

# %%
# 2000
url = url_template + str(2000)

temp_df = pd.read_html(url, header=0)[0]
temp_df.head()
temp_df.columns.values[2] = "Artist"
temp_df = temp_df.drop(temp_df.columns[0], axis=1)
temp_df.Artist = [artist.split(' featuring')[0] for artist in temp_df.Artist]
temp_df.Title = [title.strip('\"') for title in temp_df.Title]
temp_df['Year'] = 2000

billboard100_df = billboard100_df.append(temp_df)

# %%
# 2001
url = url_template + str(2001)

temp_df = pd.read_html(url, header=0)[0]
temp_df.head()
temp_df.columns.values[2] = "Artist"
temp_df = temp_df.drop(temp_df.columns[0], axis=1)
temp_df.Artist = [artist.split(' featuring')[0] for artist in temp_df.Artist]
temp_df.Title = [title.strip('\"') for title in temp_df.Title]
temp_df['Year'] = 2001

billboard100_df = billboard100_df.append(temp_df)

# %%
# 2002
url = url_template + str(2002)

temp_df = pd.read_html(url, header=0)[0]
temp_df.head()
temp_df.columns.values[2] = "Artist"
temp_df = temp_df.drop(temp_df.columns[0], axis=1)
temp_df.Artist = [artist.split(' featuring')[0] for artist in temp_df.Artist]
temp_df.Title = [title.strip('\"') for title in temp_df.Title]
temp_df['Year'] = 2002

billboard100_df = billboard100_df.append(temp_df)

# %%
# 2003
url = url_template + str(2003)

temp_df = pd.read_html(url, header=0)[0]
temp_df.head()
temp_df.columns.values[2] = "Artist"
temp_df = temp_df.drop(temp_df.columns[0], axis=1)
temp_df.Artist = [artist.split(' featuring')[0] for artist in temp_df.Artist]
temp_df.Title = [title.strip('\"') for title in temp_df.Title]
temp_df['Year'] = 2003

billboard100_df = billboard100_df.append(temp_df)

# %%
# 2004
url = url_template + str(2004)

temp_df = pd.read_html(url, header=0)[0]
temp_df.head()
temp_df.columns.values[2] = "Artist"
temp_df = temp_df.drop(temp_df.columns[0], axis=1)
temp_df.Artist = [artist.split(' featuring')[0] for artist in temp_df.Artist]
temp_df.Title = [title.strip('\"') for title in temp_df.Title]
temp_df['Year'] = 2004

billboard100_df = billboard100_df.append(temp_df)

# %%
# 2005
url = url_template + str(2005)

temp_df = pd.read_html(url, header=0)[0]
temp_df.head()
temp_df.columns.values[2] = "Artist"
temp_df = temp_df.drop(temp_df.columns[0], axis=1)
temp_df.Artist = [artist.split(' featuring')[0] for artist in temp_df.Artist]
temp_df.Title = [title.strip('\"') for title in temp_df.Title]
temp_df['Year'] = 2005

billboard100_df = billboard100_df.append(temp_df)

# %%
# 2006
url = url_template + str(2006)

temp_df = pd.read_html(url, header=0)[0]
temp_df.head()
temp_df.columns.values[2] = "Artist"
temp_df = temp_df.drop(temp_df.columns[0], axis=1)
temp_df.Artist = [artist.split(' featuring')[0] for artist in temp_df.Artist]
temp_df.Title = [title.strip('\"') for title in temp_df.Title]
temp_df['Year'] = 2006

billboard100_df = billboard100_df.append(temp_df)

# %%
# 2007
url = url_template + str(2007)

temp_df = pd.read_html(url, header=0)[0]
temp_df.head()
temp_df.columns.values[2] = "Artist"
temp_df = temp_df.drop(temp_df.columns[0], axis=1)
temp_df.Artist = [artist.split(' featuring')[0] for artist in temp_df.Artist]
temp_df.Title = [title.strip('\"') for title in temp_df.Title]
temp_df['Year'] = 2007

billboard100_df = billboard100_df.append(temp_df)

# %%
# 2008
url = url_template + str(2008)

temp_df = pd.read_html(url, header=0)[0]
temp_df.head()
temp_df.columns.values[2] = "Artist"
temp_df = temp_df.drop(temp_df.columns[0], axis=1)
temp_df.Artist = [artist.split(' featuring')[0] for artist in temp_df.Artist]
temp_df.Title = [title.strip('\"') for title in temp_df.Title]
temp_df['Year'] = 2008

billboard100_df = billboard100_df.append(temp_df)

# %%
# 2009
url = url_template + str(2009)

temp_df = pd.read_html(url, header=0)[0]
temp_df.head()
temp_df.columns.values[2] = "Artist"
temp_df = temp_df.drop(temp_df.columns[0], axis=1)
temp_df.Artist = [artist.split(' featuring')[0] for artist in temp_df.Artist]
temp_df.Title = [title.strip('\"') for title in temp_df.Title]
temp_df['Year'] = 2009

billboard100_df = billboard100_df.append(temp_df)

# %%
# 2010
url = url_template + str(2010)

temp_df = pd.read_html(url, header=0)[0]
temp_df.head()
temp_df.columns.values[2] = "Artist"
temp_df = temp_df.drop(temp_df.columns[0], axis=1)
temp_df.Artist = [artist.split(' featuring')[0] for artist in temp_df.Artist]
temp_df.Title = [title.strip('\"') for title in temp_df.Title]
temp_df['Year'] = 2010

billboard100_df = billboard100_df.append(temp_df)

# %%
# 2011
url = url_template + str(2011)

temp_df = pd.read_html(url, header=0)[0]
temp_df.head()
temp_df.columns.values[2] = "Artist"
temp_df = temp_df.drop(temp_df.columns[0], axis=1)
temp_df.Artist = [artist.split(' featuring')[0] for artist in temp_df.Artist]
temp_df.Title = [title.strip('\"') for title in temp_df.Title]
temp_df['Year'] = 2011

billboard100_df = billboard100_df.append(temp_df)

# %%
# 2012
url = url_template + str(2012)

temp_df = pd.read_html(url, header=0)[1]
temp_df.head()
temp_df.columns.values[2] = "Artist"
temp_df = temp_df.drop(temp_df.columns[0], axis=1)
temp_df.Artist = [artist.split(' featuring')[0] for artist in temp_df.Artist]
temp_df.Title = [title.strip('\"') for title in temp_df.Title]
temp_df['Year'] = 2012

billboard100_df = billboard100_df.append(temp_df)

# %%
# 2013
url = url_template + str(2013)

temp_df = pd.read_html(url, header=0)[1]
temp_df.head()
temp_df.columns.values[2] = "Artist"
temp_df = temp_df.drop(temp_df.columns[0], axis=1)
temp_df.Artist = [artist.split(' featuring')[0] for artist in temp_df.Artist]
temp_df.Title = [title.strip('\"') for title in temp_df.Title]
temp_df['Year'] = 2013

billboard100_df = billboard100_df.append(temp_df)

# %%
# 2014
url = url_template + str(2014)

temp_df = pd.read_html(url, header=0)[0]
temp_df.head()
temp_df.columns.values[2] = "Artist"
temp_df = temp_df.drop(temp_df.columns[0], axis=1)
temp_df.Artist = [artist.split(' featuring')[0] for artist in temp_df.Artist]
temp_df.Title = [title.strip('\"') for title in temp_df.Title]
temp_df['Year'] = 2014

billboard100_df = billboard100_df.append(temp_df)

# %%
# 2015
url = url_template + str(2015)

temp_df = pd.read_html(url, header=0)[0]
temp_df.head()
temp_df.columns.values[2] = "Artist"
temp_df = temp_df.drop(temp_df.columns[0], axis=1)
temp_df.Artist = [artist.split(' featuring')[0] for artist in temp_df.Artist]
temp_df.Title = [title.strip('\"') for title in temp_df.Title]
temp_df['Year'] = 2015

billboard100_df = billboard100_df.append(temp_df)

# %%
# 2016
url = url_template + str(2016)

temp_df = pd.read_html(url, header=0)[0]
temp_df.head()
temp_df.columns.values[2] = "Artist"
temp_df = temp_df.drop(temp_df.columns[0], axis=1)
temp_df.Artist = [artist.split(' featuring')[0] for artist in temp_df.Artist]
temp_df.Title = [title.strip('\"') for title in temp_df.Title]
temp_df['Year'] = 2016

billboard100_df = billboard100_df.append(temp_df)

# %%
# 2017
url = url_template + str(2017)

temp_df = pd.read_html(url, header=0)[0]
temp_df.head()
temp_df.columns.values[2] = "Artist"
temp_df = temp_df.drop(temp_df.columns[0], axis=1)
temp_df.Artist = [artist.split(' featuring')[0] for artist in temp_df.Artist]
temp_df.Title = [title.strip('\"') for title in temp_df.Title]
temp_df['Year'] = 2017

billboard100_df = billboard100_df.append(temp_df)

# %%
# 2018
url = url_template + str(2018)

temp_df = pd.read_html(url, header=0)[0]
temp_df.head()
temp_df.columns.values[2] = "Artist"
temp_df = temp_df.drop(temp_df.columns[0], axis=1)
temp_df.Artist = [artist.split(' featuring')[0] for artist in temp_df.Artist]
temp_df.Title = [title.strip('\"') for title in temp_df.Title]
temp_df['Year'] = 2018

billboard100_df = billboard100_df.append(temp_df)

# %%
billboard100_df = billboard100_df.reset_index(drop=True)
billboard100_df['Year'] = pd.to_numeric(billboard100_df['Year'])
billboard100_df['Title'] = billboard100_df['Title'].astype(str)
billboard100_df['Artist'] = billboard100_df['Artist'].astype(str)

# %%
billboard100_df
# Out:
#                            Title  \
# 0                        Breathe
# 1                         Smooth
# 2                    Maria Maria
# 3                   I Wanna Know
# 4            Everything You Want
# 5                    Say My Name
# 6             I Knew I Loved You
# 7                         Amazed
# 8                           Bent
# 9           He Wasn't Man Enough
# 10                        Higher
# 11                     Try Again
# 12              Jumpin', Jumpin'
# 13                    Thong Song
# 14                    Kryptonite
# 15                  There You Go
# 16                         Music
# 17         Doesn't Really Matter
# 18             What a Girl Wants
# 19                   Back at One
# 20                   Bye Bye Bye
# 21                You Sang to Me
# 22                I Need to Know
# 23              Get It On Tonite
# 24                    Incomplete
# 25                         I Try
# 26              It's Gonna Be Me
# 27          That's The Way It Is
# 28    Country Grammar (Hot Shit)
# 29            Bring It All to Me
# ...                          ...
# 1870                Shape of You
# 1871               I Get the Bag
# 1872                  No Brainer
# 1873                  Plain Jane
# 1874                  Sky Walker
# 1875                    Marry Me
# 1876                    Eastside
# 1877            Call Out My Name
# 1878                 King's Dead
# 1879                     Happier
# 1880                     Te Boté
# 1881                      Simple
# 1882                       Lemon
# 1883              1-800-273-8255
# 1884               Say Something
# 1885                   I'm Upset
# 1886                   Get Along
# 1887                   Moonlight
# 1888              What Lovers Do
# 1889                           X
# 1890               Outside Today
# 1891                        Trip
# 1892                        Dura
# 1893                     Changes
# 1894                       Mercy
# 1895             One Number Away
# 1896                  Powerglide
# 1897                       IDGAF
# 1898                    Mi Gente
# 1899                    Believer
#
#                                                 Artist  Year
# 0                                           Faith Hill  2000
# 1                                              Santana  2000
# 2                                              Santana  2000
# 3                                                  Joe  2000
# 4                                     Vertical Horizon  2000
# 5                                      Destiny's Child  2000
# 6                                        Savage Garden  2000
# 7                                             Lonestar  2000
# 8                                      Matchbox Twenty  2000
# 9                                         Toni Braxton  2000
# 10                                               Creed  2000
# 11                                             Aaliyah  2000
# 12                                     Destiny's Child  2000
# 13                                               Sisqó  2000
# 14                                        3 Doors Down  2000
# 15                                                Pink  2000
# 16                                             Madonna  2000
# 17                                       Janet Jackson  2000
# 18                                  Christina Aguilera  2000
# 19                                      Brian McKnight  2000
# 20                                             'N Sync  2000
# 21                                        Marc Anthony  2000
# 22                                        Marc Anthony  2000
# 23                                      Montell Jordan  2000
# 24                                               Sisqó  2000
# 25                                           Macy Gray  2000
# 26                                             'N Sync  2000
# 27                                         Celine Dion  2000
# 28                                               Nelly  2000
# 29                                              Blaque  2000
# ...                                                ...   ...
# 1870                                        Ed Sheeran  2018
# 1871                                        Gucci Mane  2018
# 1872                                         DJ Khaled  2018
# 1873                                         ASAP Ferg  2018
# 1874                                            Miguel  2018
# 1875                                      Thomas Rhett  2018
# 1876                   Benny Blanco, Halsey and Khalid  2018
# 1877                                        The Weeknd  2018
# 1878  Jay Rock, Kendrick Lamar, Future and James Blake  2018
# 1879                           Marshmello and Bastille  2018
# 1880              Nio García, Darell and Casper Mágico  2018
# 1881                              Florida Georgia Line  2018
# 1882                               N.E.R.D and Rihanna  2018
# 1883                                             Logic  2018
# 1884                                 Justin Timberlake  2018
# 1885                                             Drake  2018
# 1886                                     Kenny Chesney  2018
# 1887                                      XXXTentacion  2018
# 1888                                          Maroon 5  2018
# 1889                            Nicky Jam and J Balvin  2018
# 1890                        YoungBoy Never Broke Again  2018
# 1891                                          Ella Mai  2018
# 1892                                      Daddy Yankee  2018
# 1893                                      XXXTentacion  2018
# 1894                                       Brett Young  2018
# 1895                                        Luke Combs  2018
# 1896                                      Rae Sremmurd  2018
# 1897                                          Dua Lipa  2018
# 1898                        J Balvin and Willy William  2018
# 1899                                   Imagine Dragons  2018
#
# [1900 rows x 3 columns]

# %%
billboard100_df.to_csv('billboard.csv')
