# %%
import pandas as pd

# %% [markdown]
# # Cleaning Spotify Songs

# %%
spotify_songs = pd.read_csv('data/song_info.csv')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-2-0023a5250c1f> in <module>
# ----> 1 spotify_songs = pd.read_csv('data/song_info.csv')
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/io/parsers.py in parser_f(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, dialect, tupleize_cols, error_bad_lines, warn_bad_lines, delim_whitespace, low_memory, memory_map, float_precision)
#     700                     skip_blank_lines=skip_blank_lines)
#     701
# --> 702         return _read(filepath_or_buffer, kwds)
#     703
#     704     parser_f.__name__ = name
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/io/parsers.py in _read(filepath_or_buffer, kwds)
#     427
#     428     # Create the parser.
# --> 429     parser = TextFileReader(filepath_or_buffer, **kwds)
#     430
#     431     if chunksize or iterator:
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/io/parsers.py in __init__(self, f, engine, **kwds)
#     893             self.options['has_index_names'] = kwds['has_index_names']
#     894
# --> 895         self._make_engine(self.engine)
#     896
#     897     def close(self):
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/io/parsers.py in _make_engine(self, engine)
#    1120     def _make_engine(self, engine='c'):
#    1121         if engine == 'c':
# -> 1122             self._engine = CParserWrapper(self.f, **self.options)
#    1123         else:
#    1124             if engine == 'python':
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/io/parsers.py in __init__(self, src, **kwds)
#    1851         kwds['usecols'] = self.usecols
#    1852
# -> 1853         self._reader = parsers.TextReader(src, **kwds)
#    1854         self.unnamed_cols = self._reader.unnamed_cols
#    1855
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader.__cinit__()
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader._setup_parser_source()
#
# FileNotFoundError: [Errno 2] File b'data/song_info.csv' does not exist: b'data/song_info.csv'

# %%
spotify_songs = spotify_songs.drop('album_names', 1)
spotify_songs = spotify_songs.drop('playlist', 1)

spotify_songs = spotify_songs.rename(columns={"song_name": "Title", "artist_name": "Artist"})

spotify_songs = spotify_songs.drop_duplicates(subset="Title", keep="first")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-1193343efc25> in <module>
# ----> 1 spotify_songs = spotify_songs.drop('album_names', 1)
#       2 spotify_songs = spotify_songs.drop('playlist', 1)
#       3
#       4 spotify_songs = spotify_songs.rename(columns={"song_name": "Title", "artist_name": "Artist"})
#       5
#
# NameError: name 'spotify_songs' is not defined

# %% [markdown]
# # Cleaning Billboard Songs

# %%
billboard = pd.read_csv('data/billboard.csv', index_col=0)

# %%
billboard = billboard.drop('Year', 1)
billboard = billboard.drop_duplicates(subset="Title", keep="first")

# %% [markdown]
# # Combining DataFrames

# %%
spotify_songs['Top100'] = 0
billboard['Top100'] = 1

# %%
combined_df = pd.concat([spotify_songs, billboard], ignore_index=True, sort=True)

# %%
combined_df = combined_df.drop_duplicates(subset="Title", keep="last")

# %%
combined_df
# Out:
#                                                  Artist  \
# 1                                           Linkin Park
# 2                                     The White Stripes
# 3                                 Red Hot Chili Peppers
# 5                                           Evanescence
# 6                                            Papa Roach
# 9                                         Kings of Leon
# 12                                       Alien Ant Farm
# 13                                Red Hot Chili Peppers
# 14                                     System Of A Down
# 15                                      Franz Ferdinand
# 16                                            blink-182
# 20                               Thirty Seconds To Mars
# 22                              Queens of the Stone Age
# 23                                              Caesars
# 24                                                 Muse
# 27                                            Green Day
# 30                                         Foo Fighters
# 33                                     Three Days Grace
# 34                                          Limp Bizkit
# 35                                               Sum 41
# 36                                         Foo Fighters
# 37                                         Rise Against
# 38                                        Drowning Pool
# 40                                          The Strokes
# 41                                           Stone Sour
# 42                                    Breaking Benjamin
# 43                                            Disturbed
# 44                                              Incubus
# 45                                               P.O.D.
# 46                                                   U2
# ...                                                 ...
# 14704                                           Cardi B
# 14705                                     Ariana Grande
# 14706                                                YG
# 14707                                      Charlie Puth
# 14708                                               Max
# 14709                        Calvin Harris and Dua Lipa
# 14710                                   Imagine Dragons
# 14711                                      Jason Aldean
# 14712                                         DJ Khaled
# 14713                                         ASAP Ferg
# 14714                                            Miguel
